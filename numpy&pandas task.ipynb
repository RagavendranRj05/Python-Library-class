# %%
import pandas as pd

# %%
df = pd.read_csv("Emp21.csv",index_col=0)
df
# Out:
#    First Name    Last Name  Gender  Start Date  Years              Department  \
# No
# 1      Ghadir        Hmshw    Male    4/4/2018      7         Quality Control
# 2        Omar       Hishan    Male   5/21/2020      5         Quality Control
# 3       Ailya       Sharaf  Female   9/28/2017      8      Major Mfg Projects
# 4        Lwiy        Qbany    Male   8/14/2018      7           Manufacturing
# 5       Ahmad        Bikri    Male   3/11/2020      5           Manufacturing
# 6     Muhamad       Zueitr    Male    2/2/2016      9     Product Development
# 7         Iin    Alhalaliu  Female    5/8/2020      5                   Sales
# 8     Muhamad        Alaya    Male   2/10/2018      7      Account Management
# 9       Susin      Almilat  Female   3/11/2018      7          Green Building
# 10    Muhamad     Alrifaei    Male    1/3/2020      6      Account Management
# 11    Muhamad      Alqadah    Male   1/16/2018      7           Manufacturing
# ...

# %%
df[df["Years"]>5]
# Out:
#    First Name    Last Name  Gender  Start Date  Years              Department  \
# No
# 1      Ghadir        Hmshw    Male    4/4/2018      7         Quality Control
# 3       Ailya       Sharaf  Female   9/28/2017      8      Major Mfg Projects
# 4        Lwiy        Qbany    Male   8/14/2018      7           Manufacturing
# 6     Muhamad       Zueitr    Male    2/2/2016      9     Product Development
# 8     Muhamad        Alaya    Male   2/10/2018      7      Account Management
# 9       Susin      Almilat  Female   3/11/2018      7          Green Building
# 10    Muhamad     Alrifaei    Male    1/3/2020      6      Account Management
# 11    Muhamad      Alqadah    Male   1/16/2018      7           Manufacturing
# 12    Muhamad          Iad    Male   7/19/2018      7                      IT
# 13     Razaan        Nasif  Female  11/11/2018      7  Facilities/Engineering
# 14     Iilian          Dbs  Female    3/1/2016      9  Facilities/Engineering
# ...

# %%
df[df['Gender']=='Female']
# Out:
#    First Name    Last Name  Gender  Start Date  Years              Department  \
# No
# 3       Ailya       Sharaf  Female   9/28/2017      8      Major Mfg Projects
# 7         Iin    Alhalaliu  Female    5/8/2020      5                   Sales
# 9       Susin      Almilat  Female   3/11/2018      7          Green Building
# 13     Razaan        Nasif  Female  11/11/2018      7  Facilities/Engineering
# 14     Iilian          Dbs  Female    3/1/2016      9  Facilities/Engineering
# 15      Bayan          Qdw  Female   12/4/2018      7               Marketing
# 17     Sandra  Aljurmqaniu  Female   5/27/2016      9      Account Management
# 19       Ahed        Salim  Female   4/24/2018      7         Quality Control
#
#                  Country Center  Monthly Salary  Annual Salary  Job Rate  \
# No
# 3           Saudi Arabia   West            2506          30072       2.0
# 7   United Arab Emirates   Main            1959          23508       3.0
# ...

# %%
df.groupby("Department")["Annual Salary"].sum()
# Out:
# Department
# Account Management        110448
# Facilities/Engineering     64836
# Green Building             17748
# IT                         24192
# Major Mfg Projects         30072
# Manufacturing              51396
# Marketing                  10668
# Product Development        54144
# Quality Control            99168
# Sales                      34668
# Name: Annual Salary, dtype: int64

# %%
df.drop(columns=["Center"])
# Out:
#    First Name    Last Name  Gender  Start Date  Years              Department  \
# No
# 1      Ghadir        Hmshw    Male    4/4/2018      7         Quality Control
# 2        Omar       Hishan    Male   5/21/2020      5         Quality Control
# 3       Ailya       Sharaf  Female   9/28/2017      8      Major Mfg Projects
# 4        Lwiy        Qbany    Male   8/14/2018      7           Manufacturing
# 5       Ahmad        Bikri    Male   3/11/2020      5           Manufacturing
# 6     Muhamad       Zueitr    Male    2/2/2016      9     Product Development
# 7         Iin    Alhalaliu  Female    5/8/2020      5                   Sales
# 8     Muhamad        Alaya    Male   2/10/2018      7      Account Management
# 9       Susin      Almilat  Female   3/11/2018      7          Green Building
# 10    Muhamad     Alrifaei    Male    1/3/2020      6      Account Management
# 11    Muhamad      Alqadah    Male   1/16/2018      7           Manufacturing
# ...

# %%
df.groupby("Department")["Unpaid Leaves"].sum()
# Out:
# Department
# Account Management        0
# Facilities/Engineering    0
# Green Building            0
# IT                        0
# Major Mfg Projects        3
# Manufacturing             5
# Marketing                 1
# Product Development       0
# Quality Control           5
# Sales                     0
# Name: Unpaid Leaves, dtype: int64
