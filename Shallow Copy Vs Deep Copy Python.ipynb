# %%
## =,copy(),deepcopy()
lst1=[1,2,3,4]
lst2=lst1
print(lst2)
# Out:
# [1, 2, 3, 4]

# %%
print(lst1)
# Out:
# [1, 2, 3, 4]

# %%
lst2[1]=1000

# %%
lst2
# Out:
# [1, 1000, 3, 4]

# %%
lst1
# Out:
# [1, 1000, 3, 4]

# %%
##copy
## Shallow Copy
lst1=[1,2,3,4]   # lst1 -> orginal list
lst2=lst1.copy()  # lst2 -> copy of list1
print(lst2)
# Out:
# [1, 2, 3, 4]

# %%
lst2[1]=100

# %%
lst2
# Out:
# [1, 100, 3, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
lst3 = [7,8,9,0]  # lst3-> orginal list
lst4 = lst3.copy()  # lst4 -> copy

# %%
lst3[2] = 10
lst3
# Out:
# [7, 8, 10, 0]

# %%
lst4
# Out:
# [7, 8, 9, 0]

# %%
## Shallow Copy nested list
lst1=[[1,2,3,4],[5,6,7,8]]  # lst1-> orginal list
lst2=lst1.copy()             # lst2 -> copy

# %%
lst1[1][0]=10

# %%
lst1
# Out:
# [[1, 2, 3, 4], [10, 6, 7, 8]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [10, 6, 7, 8]]

# %%
lst5 = [[9,10,11,12],[13,14,15,16]]  # orginal
lst6 = lst5.copy()    # copy

# %%
lst6[1][1]= 20
lst6
# Out:
# [[9, 10, 11, 12], [13, 20, 15, 16]]

# %%
lst5
# Out:
# [[9, 10, 11, 12], [13, 20, 15, 16]]

# %%
lst1.append([2,3,4,5])

# %%
lst1
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8], [2, 3, 4, 5]]

# %%
lst2
# Out:
# [[1, 2, 3, 4], [100, 6, 7, 8]]

# %%
##deep copy
import copy
lst1=[1,2,3,4]
lst2=copy.deepcopy(lst1)

# %%
lst2[1]=100

# %%
lst2
# Out:
# [1, 100, 3, 4]

# %%
lst1
# Out:
# [1, 2, 3, 4]

# %%
lst3 = [7,8,9,0]  # lst3-> orginal list
lst4 = copy.deepcopy(lst3)  # lst4 -> copy

# %%
lst3[1] = 11
lst3
# Out:
# [7, 11, 9, 0]

# %%
lst4
# Out:
# [7, 8, 9, 0]

# %%
### In a normal list shallow ===deep copy

# %%
lst1=[[1,2,3],[3,4,5,],[5,6,7]]
lst2=copy.deepcopy(lst1)

# %%
lst2[1][0]=100

# %%
lst2
# Out:
# [[1, 2, 3], [100, 4, 5], [5, 6, 7]]

# %%
lst1
# Out:
# [[1, 2, 3], [3, 4, 5], [5, 6, 7]]

# %%
lst5 = [[9,10,11,12],[13,14,15,16]]  # orginal
lst6 = copy.deepcopy(lst5)    # copy

# %%
lst5[0][0] = 8
lst5
# Out:
# [[8, 10, 11, 12], [13, 14, 15, 16]]

# %%
lst6
# Out:
# [[9, 10, 11, 12], [13, 14, 15, 16]]
