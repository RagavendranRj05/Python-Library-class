# %%
import numpy as np

# %%
lst1 = [1,2,3,4,5,6]
lst1
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
arr = np.array(lst1)
arr
# Out:
# array([1, 2, 3, 4, 5, 6])

# %%
type(arr)
# Out:
# numpy.ndarray

# %%
lst2 = [30,40,50,60,70]
lst3 = [15,25,35,45,55]
lst4 = [2,4,6,8,10]

arr1 = np.array([lst2,lst3,lst4])
arr1
# Out:
# array([[30, 40, 50, 60, 70],
#        [15, 25, 35, 45, 55],
#        [ 2,  4,  6,  8, 10]])

# %%
arr1[1:3,2:]
# Out:
# array([[35, 45, 55],
#        [ 6,  8, 10]])
